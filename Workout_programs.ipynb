# %% [markdown]
# <a href="https://colab.research.google.com/github/subakarthik753/Python_Workout_programs/blob/main/Workout_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Subakarthik")
print("o----")
print(" ||||")

# %% [markdown]
# Variables

# %%
price = 99.99
price = 199.99
is_published = True
print("The price is" ,price)
print(is_published)
print(type(price))
# Out:
# The price is 199.99
# True
# <class 'float'>

# %%
Name = input("Enter your Name:")
Color = input("Enter yout Favourite color:")
print("The name is" ,Name, "and he likes" ,Color, "Color")
# Out:
# Enter your Name:kasdb
# Enter yout Favourite color:kjhbfd
# The name is kasdb and he likes kjhbfd Color

# %%
Birth_year = int(input("Enter your birth year:"))
#Year = 2026
Age = 2026 - Birth_year
print(Age)
# Out:
# Enter your birth year:2005
# 21

# %%
Weight_lbs = int(input("Enter your Weight in pounds:"))
Weight_kg = Weight_lbs * 0.45
print("Your weight in KG was" ,Weight_kg)
# Out:
# Enter your Weight in pounds:200
# Your weight in KG was 90.0

# %%
course = "Python for beginners"
print(course[1:-1])
# Out:
# ython for beginner

# %%
first = "Suba"
last = "Karthik"
message = first + "["+ last + "] is a coder"
msg = f"{first}[{last}] is a coder"
print(message)
print(msg)
# Out:
# Suba[Karthik] is a coder
# Suba[Karthik] is a coder

# %%
courses = "Python for beginners"
print(len(course))
print(courses.upper())
print(courses.lower())
print(courses.title())  #To give every words starting letter in caps
print(courses.find('g'))
print(courses.replace('beginners', "Absolute beginners"))
print('python' in courses) #To search this particular word in a line or file and it is case sensitive
# Out:
# 20
# PYTHON FOR BEGINNERS
# python for beginners
# Python For Beginners
# 13
# Python for Absolute beginners
# False

# %%
x = (2 + 3) * 10 -3
y = 9.59
print(round(y))
print(x)
print(abs(-98765432))
# Out:
# 10
# 47
# 98765432

# %%
import math
x = 10
print(math.ceil(2.9))
print(math.floor(2.9))
# Out:
# 3
# 2

# %%
temperature = int(input("Enter the current temperature:"))

if(temperature >= 25):
  print('''It's a hot day
Drink plenty of water''')
elif(temperature <= 20):
  print('''It's a cold day
Wear warm cloths''')
else:
  print("It's a lovely day")
# Out:
# Enter the current temperature:22
# It's a lovely day

# %%
price = 1000000
has_good_credit = True
if has_good_credit:
  down_payment = 0.1 * price
else:
  down_payment = 0.2 * price
print(f"Down payment: ${down_payment}")
# Out:
# Down payment: $100000.0
